# %%
print('hello')
# Out:
# hello

# %%
with open("./geeks.txt", "r") as file:
    content = file.read()
    print(content)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Saikiran\Downloads\us_customer_data 1.csv")
print(df1)
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df2 = pd.read_csv(r"C:\Users\Saikiran\Downloads\transaction_data.csv")
print(df2)
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 0                 1          565  2992.47  2025-03-10 01:20:54
# 1                 2          323  2041.87  2025-01-02 15:24:19
# 2                 3          398   107.35  2025-02-16 03:49:01
# 3                 4           19      NaN  2025-04-30 15:26:23
# 4                 5          547  3063.28  2025-06-14 04:28:53
# ..              ...          ...      ...                  ...
# 995             996           60   712.47  2025-01-13 14:16:32
# 996             997          235  2125.18  2025-06-09 12:37:36
# 997             998          669  3069.08  2025-04-01 19:59:01
# 998             999          931  2262.75  2025-06-08 01:36:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 0             Sports     Debit Card       New York
# 1           Clothing           Cash       New York
# 2             Beauty     Debit Card         Online
# ...

# %%
df1.head()
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# ...

# %%
df1.tail()
# Out:
#      customer_id            name                      email         phone  \
# 995          996  Jerry Mcdaniel     walkerlisa@example.net  638-989-9441
# 996          997    Jodi Simpson         eric24@example.org  483-625-2940
# 997          998   Crystal Brown       pshaffer@example.net  390-747-3088
# 998          999  Gregory Duarte  caitlindunlap@example.org  257-409-8196
# 999         1000     Jason Walls      michael42@example.com  692-333-6880
#
#                                                address registration_date  \
# 995           34746 Smith Gateway, New Sarah, AS 12715        10-02-2025
# 996  2876 Tucker Road Suite 947, North Tommyborough...        18-04-2024
# 997  095 Janice Forest Suite 570, Boltonmouth, DE 7...        30-08-2024
# 998                   Unit 6377 Box 7662, DPO AP 03300        16-05-2024
# 999             95002 Bruce Rue, Camachoport, MH 58723        10-12-2024
#
#     loyalty_status
# 995         Silver
# 996         Bronze
# 997         Bronze
# ...

# %%
df1.sample(5)
# Out:
#      customer_id            name                        email         phone  \
# 860          861      James Bass  kristenguerrero@example.com  381-618-8901
# 214          215     David Baker    andersonscott@example.com  441-602-9809
# 638          639     Brian Flynn           alan66@example.com  820-924-4570
# 963          964  Travis Johnson      marksimpson@example.com  980-319-2393
# 752          753      John Owens   johnpennington@example.net  672-644-1942
#
#                                                address registration_date  \
# 860  9861 Madison Station Apt. 248, North Morganber...        01-01-2025
# 214  5386 Park Valleys Suite 887, Johnsonhaven, GA ...        21-06-2024
# 638      0608 Wolf Court Apt. 921, Singhfurt, AZ 74522        11-06-2024
# 963    568 Joseph Mills Suite 957, East Anne, WY 20331        29-04-2024
# 752          38004 Carlos Circle, Susanmouth, MH 10958        06-06-2025
#
#     loyalty_status
# 860         Bronze
# 214         Bronze
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              950 non-null    object
#  3   phone              984 non-null    object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
df1.describe()
# Out:
#        customer_id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
print(df1.columns)
print(df1.dtypes)
#df1.rename(columns={'old_name': 'new_name'}, inplace=True)
# Out:
# Index(['customer_id', 'name', 'email', 'phone', 'address', 'registration_date',
#        'loyalty_status'],
#       dtype='object')
# customer_id           int64
# name                 object
# email                object
# phone                object
# address              object
# registration_date    object
# loyalty_status       object
# dtype: object

# %%
df1.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df1.sort_values(by='registration_date',ascending=False)
# Out:
#      customer_id              name                        email         phone  \
# 194          195    Stephanie Ruiz  frederickandrew@example.org  690-521-9720
# 286          287  Johnny Macdonald        kenneth82@example.net  210-222-6636
# 212          213    Robert Flowers    patrickpowell@example.net  802-503-1930
# 8              9    Matthew Harvey          bgaines@example.net  581-144-7338
# 181          182     Donald Thomas       changjulie@example.org  323-413-1638
# ..           ...               ...                          ...           ...
# 467          468        Alice Cruz                          NaN  682-525-6707
# 436          437        Mary Cantu      stephanie35@example.net  462-796-8389
# 860          861        James Bass  kristenguerrero@example.com  381-618-8901
# 197          198      Gregory Leon         jameslee@example.org  302-970-1181
# 824          825      April Larson          rbrooks@example.org  737-681-7224
#
# ...

# %%
df1=df1.drop_duplicates()
df1
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
import pandas as pd
df1['registration_date'] = pd.to_datetime(df1['registration_date'], errors='coerce')

df1['registration_date'] = df1['registration_date'].dt.strftime('%Y-%m-%d')
df1
# Out:
# C:\Users\Saikiran\AppData\Local\Temp\ipykernel_7112\2433771566.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['registration_date'] = pd.to_datetime(df1['registration_date'], errors='coerce')
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# ...

# %%
df1[df1['customer_id']==111]
# Out:
#      customer_id         name              email         phone  \
# 110          111  David Jones  asoto@example.com  235-207-6678
#
#                                    address registration_date loyalty_status
# 110  9445 Wells Mall, Jameshaven, GA 03460        2023-10-11         Silver

# %%
df1['email']=df1['email'].fillna(df1['name']+'@'+'gmail.com')
df1[df1['customer_id']==28]
# Out:
#     customer_id          name                   email         phone  \
# 27           28  Brandon Hall  Brandon Hall@gmail.com  974-123-3048
#
#                                              address registration_date  \
# 27  8143 Robert Cove Apt. 103, Sanchezport, CO 78231        2024-04-07
#
#    loyalty_status
# 27           Gold

# %%
df1['email']=df1['email'].str.replace(' ','')

# %%
df1[df1['customer_id']==28]
# Out:
#     customer_id          name                  email         phone  \
# 27           28  Brandon Hall  BrandonHall@gmail.com  974-123-3048
#
#                                              address registration_date  \
# 27  8143 Robert Cove Apt. 103, Sanchezport, CO 78231        2024-04-07
#
#    loyalty_status
# 27           Gold

# %%
df1[df1['customer_id']==527]
# Out:
#      customer_id         name                   email phone  \
# 526          527  Maria Moore  alexisvega@example.net     0
#
#                                                address registration_date  \
# 526  756 Gutierrez Meadow Apt. 520, West Sarahfurt,...        2025-05-01
#
#     loyalty_status
# 526           Gold

# %%
df1[df1['customer_id']==297]
# Out:
#      customer_id            name                 email phone  \
# 296          297  Bryan Marshall  daniel62@example.net     e
#
#                                                address registration_date  \
# 296  86370 Charles Loop Apt. 517, Madelineborough, ...        2024-06-30
#
#     loyalty_status
# 296         Silver

# %%
df1[df1['customer_id']==519]
# Out:
#      customer_id            name                email         phone  \
# 518          519  Michael Carter  amber60@example.net  378-353-5810
#
#                                                address registration_date  \
# 518  02563 Daniel Walks Apt. 510, Lake Robertberg, ...        2023-12-14
#
#     loyalty_status
# 518           Gold

# %%
df1[df1['customer_id']==290]
# Out:
#      customer_id         name                 email            phone  \
# 289          290  Tony Barnes  daniel85@example.com  309-515-738521e
#
#                                         address registration_date  \
# 289  162 Jeffrey Rapids, Lindsaymouth, OH 43140        2024-09-19
#
#     loyalty_status
# 289           Gold

# %%
df1['phone']=df1['phone'].str.replace(r'[a-zA-Z|(|)|-]','',regex=True)

# %%
df1['phone']=df1['phone'].str.slice(0,10)

# %%
import numpy as np
df1['phone'] = df1['phone'].apply(lambda x:np.nan if len(str(x)) <10 else x)

# %%
df1['phone']
# Out:
# 0      6197234258
# 1      5376741158
# 2      8102564505
# 3      4232229779
# 4      2207633522
#           ...
# 995    6389899441
# 996    4836252940
# 997    3907473088
# 998    2574098196
# 999    6923336880
# Name: phone, Length: 1000, dtype: object

# %%
df1[df1['customer_id']==445]
# Out:
#      customer_id          name                  email       phone  \
# 444          445  Mallory Mann  charles11@example.net  8995804497
#
#                                                address registration_date  \
# 444  14758 Bautista Fords Apt. 251, Sandrachester, ...        2024-10-23
#
#     loyalty_status
# 444           Gold

# %%
#Processing customer data from a CSV file for a retail company to ensure clean, unique records.
df1['phone'] = df1['phone'].fillna('9999999999')

df1.head()
# Out:
#    customer_id              name                        email       phone  \
# 0            1     Michelle Kidd           vayala@example.net  6197234258
# 1            2       Brad Newton  taylorcatherine@example.net  5376741158
# 2            3      Larry Torres         dsanchez@example.net  8102564505
# 3            4    Kimberly Price    jessicaknight@example.com  4232229779
# 4            5  Matthew Phillips        qwilliams@example.com  2207633522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        2025-01-25
# 1  38783 Oliver Street, West Kristenborough, MT 9...        2023-07-13
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        2023-08-18
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        2024-12-08
# 4  2274 Williams Heights Suite 895, Andersonhaven...        2024-02-03
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# 3           Gold
# ...

# %%
df1['phone']='+91 '+df1['phone']
df1
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#               phone                                            address  \
# 0    +91 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df1.to_csv(r"C:\Users\Saikiran\Downloads\cus_data.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB
