# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import pandas as pd
import numpy as np

# %%
engine = create_engine(
    "mssql+pyodbc://sa:Kasmo%40123@DESKTOP-OLVG7PI/newdata?driver=ODBC+Driver+17+for+SQL+Server",
    fast_executemany=True)

# %%
df=pd.read_sql('select * from cus_data',con=engine)

# %%
df1=df.head(10)
df1
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd                sai@gmail.com
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3           Larry Torres         dsanchez@example.net
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            8    Melissa Galloway MD   watsonbenjamin@example.net
# 8            9         Matthew Harvey          bgaines@example.net
# 9           10           Rachel White     whitemichael@example.org
#
#             phone                                            address  \
# 0   +917568099123                                      mindspace,hyd
# 1  +91 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
id=int(input('enter the customer_id'))
addr=input('enter the address')
mail=input('enter the mail')

# %%
df1['status']='active'
# Out:
# C:\Users\Saikiran\AppData\Local\Temp\ipykernel_25500\2209108223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['status']='active'

# %%
df1
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd                sai@gmail.com
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3           Larry Torres         dsanchez@example.net
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            8    Melissa Galloway MD   watsonbenjamin@example.net
# 8            9         Matthew Harvey          bgaines@example.net
# 9           10           Rachel White     whitemichael@example.org
#
#             phone                                            address  \
# 0   +917568099123                                      mindspace,hyd
# 1  +91 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
df1.to_sql('scd_2',engine,if_exists='replace',index=False)
# Out:
# -1

# %%
query=f'''update scd_2
          set status='inactive'
          where customer_id={id}
          '''

# %%
with engine.connect() as conn:
    conn.execute(text(query))
    conn.commit()

# %%
row=df1.iloc[0]
row
# Out:
# customer_id                      1
# name                 Michelle Kidd
# email                sai@gmail.com
# phone                +917568099123
# address              mindspace,hyd
# registration_date       2025-01-25
# loyalty_status                Gold
# status                      active
# Name: 0, dtype: object

# %%
query1=f'''insert into cus_data(customer_id,name,email,phone,address,registration_date,loyalty_status,status)
            values({row['customer_id']},'{row['name']}','{mail}','{row['phone']}','{addr}','{row['registration_date']}','{row['loyalty_status']}','{row['status']}')
'''
with engine.connect() as conn:
    conn.execute(query1)
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Saikiran\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:1411, in Connection.execute(self, statement, parameters, execution_options)
#    1410 try:
# -> 1411     meth = statement._execute_on_connection
#    1412 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[24], line 5
#       1 query1=f'''insert into cus_data(customer_id,name,email,phone,address,registration_date,loyalty_status,status)
#       2             values({row['customer_id']},'{row['name']}','{mail}','{row['phone']}','{addr}','{row['registration_date']}','{row['loyalty_status']}','{row['status']}')
# ...
