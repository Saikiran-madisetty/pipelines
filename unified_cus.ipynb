# %%
import pandas as pd
import pyodbc
server = 'DESKTOP-OLVG7PI'
database = 'newdata'
username = 'sa'
password = 'Kasmo@123'
driver = '{ODBC Driver 17 for SQL Server}'

# %%
connection_string=f"DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}"
conn=pyodbc.connect(connection_string)
cursor=conn.cursor()

# %%
from sqlalchemy import create_engine
engine = create_engine(
    "mssql+pyodbc://sa:Kasmo%40123@DESKTOP-OLVG7PI/newdata?driver=ODBC+Driver+17+for+SQL+Server",
    fast_executemany=True)

# %%
df_cus = pd.read_csv(r"C:\Users\Saikiran\Downloads\order_data 1.csv")

# %%
df_orders = pd.read_csv(r"C:\Users\Saikiran\Downloads\cus_data.csv")

# %%
df_cus.to_sql('only_customer', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
df_orders.to_sql('orders', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
customers_df = pd.read_sql("SELECT * FROM only_customer", con=engine)
orders_df = pd.read_sql("SELECT * FROM orders", con=engine)

unified_df = pd.merge(customers_df, orders_df, how='inner', on='customer_id')

# %%
unified_df
# Out:
#                                   order_id  customer_id  order_date  \
# 0     892a07a4-d252-4775-85e0-73077143e1c6          966  2024-11-27
# 1     ae160758-e187-47b2-9350-032f88f55491          345  2023-03-27
# 2     7c50456e-6123-45cc-aa19-128bef3754d6          503  2024-03-31
# 3     c788b56b-3716-4cd9-a827-d4dc401ba00c          385  2023-08-09
# 4     925ab5b1-adb1-4302-a70b-1c2db724e02b          817  2023-04-19
# ...                                    ...          ...         ...
# 1995  cb6f0f6b-3d4b-402c-ba9e-a8e666422d97          799  2023-11-20
# 1996  900fdea4-fd87-486d-bc20-26d045767ed8          692  2023-07-20
# 1997  4550ccfe-18c1-45d5-8c31-0edf1e3d9fa3          695  2024-01-06
# 1998  dd19b028-dfa2-4eda-a66f-44f5401ef27e          502  2023-02-05
# 1999  5e32ff66-d3dd-48ad-8e47-cd71bb2e97ea          348  2024-11-02
#
#       order_amount order_status product_category  Unnamed: 0             name  \
# ...
