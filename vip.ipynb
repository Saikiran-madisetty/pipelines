# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\Saikiran\Downloads\cus_data.csv")
df1
# Out:
#      Unnamed: 0  customer_id              name                        email  \
# 0             0            1     Michelle Kidd           vayala@example.net
# 1             1            2       Brad Newton  taylorcatherine@example.net
# 2             2            3      Larry Torres         dsanchez@example.net
# 3             3            4    Kimberly Price    jessicaknight@example.com
# 4             4            5  Matthew Phillips        qwilliams@example.com
# ..          ...          ...               ...                          ...
# 995         995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996         996          997      Jodi Simpson           eric24@example.org
# 997         997          998     Crystal Brown         pshaffer@example.net
# 998         998          999    Gregory Duarte    caitlindunlap@example.org
# 999         999         1000       Jason Walls        michael42@example.com
#
# ...

# %%
df2=pd.read_csv(r"C:\Users\Saikiran\Downloads\transaction_data.csv")
df2
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 0                 1          565  2992.47  2025-03-10 01:20:54
# 1                 2          323  2041.87  2025-01-02 15:24:19
# 2                 3          398   107.35  2025-02-16 03:49:01
# 3                 4           19      NaN  2025-04-30 15:26:23
# 4                 5          547  3063.28  2025-06-14 04:28:53
# ..              ...          ...      ...                  ...
# 995             996           60   712.47  2025-01-13 14:16:32
# 996             997          235  2125.18  2025-06-09 12:37:36
# 997             998          669  3069.08  2025-04-01 19:59:01
# 998             999          931  2262.75  2025-06-08 01:36:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 0             Sports     Debit Card       New York
# 1           Clothing           Cash       New York
# 2             Beauty     Debit Card         Online
# ...

# %%
df3=pd.merge(df1,df2,on='customer_id',how='inner')
df3
# Out:
#      Unnamed: 0  customer_id              name                        email  \
# 0             0            1     Michelle Kidd           vayala@example.net
# 1             3            4    Kimberly Price    jessicaknight@example.com
# 2             4            5  Matthew Phillips        qwilliams@example.com
# 3             6            7      Louis Miller  patriciaelliott@example.org
# 4             6            7      Louis Miller  patriciaelliott@example.org
# ..          ...          ...               ...                          ...
# 995         994          995    Deanna Johnson            ycook@example.org
# 996         994          995    Deanna Johnson            ycook@example.org
# 997         996          997      Jodi Simpson           eric24@example.org
# 998         997          998     Crystal Brown         pshaffer@example.net
# 999         997          998     Crystal Brown         pshaffer@example.net
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   customer_id        1000 non-null   int64
#  2   name               1000 non-null   object
#  3   email              1000 non-null   object
#  4   phone              1000 non-null   object
#  5   address            1000 non-null   object
#  6   registration_date  1000 non-null   object
#  7   loyalty_status     1000 non-null   object
#  8   transaction_id     1000 non-null   int64
#  9   amount             950 non-null    float64
#  10  transaction_date   1000 non-null   object
#  11  product_category   1000 non-null   object
#  12  payment_method     1000 non-null   object
#  13  store_location     1000 non-null   object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 109.5+ KB

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0            0
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
df3['amount']=df3['amount'].fillna(df3['amount'].mean())

# %%
gd=df3.groupby(['customer_id','phone','email'])['amount'].sum()
high_value=gd[gd>1000].sort_values(ascending=False)
high_value
# Out:
# customer_id  phone           email
# 488          +91 4829915642  eileen22@example.net          15704.70
# 301          +91 8564253622  jefferygarcia@example.org     13797.22
# 866          +91 1791911085  woodsangela@example.com       13699.75
# 760          +91 7084735858  andreadkins@example.org       13656.30
# 697          +91 9009478196  oduncan@example.net           13140.66
#                                                              ...
# 390          +91 2889599415  JenniferChurch@gmail.com       1060.95
# 558          +91 8273938347  justin24@example.com           1057.89
# 325          +91 1249231897  seanlopez@example.com          1024.59
# 307          +91 9999999999  xhopkins@example.net           1008.48
# 617          +91 5983323980  christinaboyer@example.org     1006.88
# Name: amount, Length: 578, dtype: float64

# %%
high_value.to_csv(r"C:\Users\Saikiran\Downloads\high_value_cust.csv")
