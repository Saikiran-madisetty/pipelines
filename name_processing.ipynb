# %%
import pandas as pd
import pyodbc
server = 'DESKTOP-OLVG7PI'
database = 'newdata'
username = 'sa'
password = 'Kasmo@123'
driver = '{ODBC Driver 17 for SQL Server}'

# %%
connection_string=f"DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}"
conn=pyodbc.connect(connection_string)
cursor=conn.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM dbo.customers", conn)
# Out:
# C:\Users\Saikiran\AppData\Local\Temp\ipykernel_4504\4072528395.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM dbo.customers", conn)

# %%
df
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#               phone                                            address  \
# 0    +91 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
prefixes = ['Mr.', 'Mr', 'Miss.', 'Miss', 'Mrs.', 'Mrs', 'Dr.', 'Dr']
 
def clean_name(name):
    parts = name.split()
    if len(parts) == 2:
        return ' '.join(parts)
    elif len(parts) == 4:
        return ' '.join(parts[1:-1])
    elif len(parts) == 3:
        if parts[0] in prefixes:
            return ' '.join(parts[1:])
        else:
            return ' '.join(parts[:-1])
    else:
        return name  
 
df['name'] = df['name'].apply(clean_name)

# %%
print(df['name'].to_string())
# Out:
# 0              Michelle Kidd
# 1                Brad Newton
# 2               Larry Torres
# 3             Kimberly Price
# 4           Matthew Phillips
# 5          Darrell Gallagher
# 6               Louis Miller
# 7           Melissa Galloway
# 8             Matthew Harvey
# 9               Rachel White
# 10               Nicole Yang
# 11         Christine Delgado
# 12            Joseph Brennan
# 13               Eric Thomas
# 14               Laura Perez
# 15             Erin Matthews
# 16          Melissa Alvarado
# 17               Ernest Dunn
# 18             David Johnson
# 19             Wayne Morales
# 20           Michael Vincent
# 21              Tammie Mcgee
# 22           Marisa Martinez
# 23          Crystal Peterson
# 24          Jeremy Alexander
# 25              James Graham
# 26          William Morrison
# 27              Brandon Hall
# 28             Morgan Wilson
# 29              Heather Hill
# 30             Louis Beasley
# 31             Julie Shelton
# ...

# %%
df[['first_name', 'last_name']] = df['name'].str.split(n=1,expand=True)

# %%
df
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#               phone                                            address  \
# 0    +91 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df.drop('name',axis=1)
# Out:
#      customer_id                        email           phone  \
# 0              1           vayala@example.net  +91 6197234258
# 1              2  taylorcatherine@example.net  +91 5376741158
# 2              3         dsanchez@example.net  +91 8102564505
# 3              4    jessicaknight@example.com  +91 4232229779
# 4              5        qwilliams@example.com  +91 2207633522
# ..           ...                          ...             ...
# 995          996       walkerlisa@example.net  +91 6389899441
# 996          997           eric24@example.org  +91 4836252940
# 997          998         pshaffer@example.net  +91 3907473088
# 998          999    caitlindunlap@example.org  +91 2574098196
# 999         1000        michael42@example.com  +91 6923336880
#
#                                                address registration_date  \
# 0                          USNS Santiago, FPO AE 80872        2025-01-25
# ...

# %%
first = df.pop('first_name')
df.insert(1, 'first_name', first)

last = df.pop('last_name')
df.insert(2, 'last_name', last)

# %%
df
# Out:
#      customer_id first_name last_name              name  \
# 0              1   Michelle      Kidd     Michelle Kidd
# 1              2       Brad    Newton       Brad Newton
# 2              3      Larry    Torres      Larry Torres
# 3              4   Kimberly     Price    Kimberly Price
# 4              5    Matthew  Phillips  Matthew Phillips
# ..           ...        ...       ...               ...
# 995          996      Jerry  Mcdaniel    Jerry Mcdaniel
# 996          997       Jodi   Simpson      Jodi Simpson
# 997          998    Crystal     Brown     Crystal Brown
# 998          999    Gregory    Duarte    Gregory Duarte
# 999         1000      Jason     Walls       Jason Walls
#
#                            email           phone  \
# 0             vayala@example.net  +91 6197234258
# 1    taylorcatherine@example.net  +91 5376741158
# 2           dsanchez@example.net  +91 8102564505
# 3      jessicaknight@example.com  +91 4232229779
# ...

# %%
#pip install pyodbc sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#from sqlalchemy import create_engine

'''conn_str = 'mssql+pyodbc://sa:Kasmo@123@DESKTOP-OLVG7PI/newdata?driver=ODBC+Driver+17+for+SQL+Server'
engine = create_engine(conn_str)'''

# %%
from sqlalchemy import create_engine
engine = create_engine(
    "mssql+pyodbc://sa:Kasmo%40123@DESKTOP-OLVG7PI/newdata?driver=ODBC+Driver+17+for+SQL+Server",
    fast_executemany=True)

# %%
df.to_sql('named_cus', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
df
# Out:
#      customer_id first_name last_name              name  \
# 0              1   Michelle      Kidd     Michelle Kidd
# 1              2       Brad    Newton       Brad Newton
# 2              3      Larry    Torres      Larry Torres
# 3              4   Kimberly     Price    Kimberly Price
# 4              5    Matthew  Phillips  Matthew Phillips
# ..           ...        ...       ...               ...
# 995          996      Jerry  Mcdaniel    Jerry Mcdaniel
# 996          997       Jodi   Simpson      Jodi Simpson
# 997          998    Crystal     Brown     Crystal Brown
# 998          999    Gregory    Duarte    Gregory Duarte
# 999         1000      Jason     Walls       Jason Walls
#
#                            email           phone  \
# 0             vayala@example.net  +91 6197234258
# 1    taylorcatherine@example.net  +91 5376741158
# 2           dsanchez@example.net  +91 8102564505
# 3      jessicaknight@example.com  +91 4232229779
# ...
